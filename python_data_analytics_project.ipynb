# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("bangalore-rainfall-data-1900-2024-sept.csv")
data
# Out:
#                 Year  Jan   Feb   Mar   Apr    May   June   July    Aug  \
# 0               1901  0.0  78.9   0.0  24.3  146.0   47.7   71.6   71.6
# 1               1902  0.7   0.0  17.0  58.1  197.8   62.2   32.0   79.5
# 2               1903  0.0   0.0   0.0   1.5   63.7  109.2   27.9  189.7
# 3               1904  0.5   0.0   0.0  14.4  241.5   49.5  149.3   53.8
# 4               1905  1.7   0.0  56.6  32.7   90.6   60.7   58.9  266.4
# ..               ...  ...   ...   ...   ...    ...    ...    ...    ...
# 121             2022  3.9   0.0   0.0  61.4  270.2  255.5  136.7  378.7
# 122             2023  0.0   0.0   8.4  28.2  305.5   72.3  141.5   12.6
# 123             2024  0.0   0.0   0.0   0.0  180.9  204.7   92.8  230.2
# 124  LPA (1991-2020)  1.7   5.9  19.2  73.0  133.0  111.0  112.8  160.2
# 125  LPA (1981-2010)  1.9   5.2  18.0  55.7  112.6  104.3  116.2  149.4
#
#       Sept    Oct    Nov   Dec   Total El NiNo (Y/N) La Nina (Y/N)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = data[(data.Year>'1999')& (data.Year<'2024')]
plt.figure(figsize=(14, 8))
plt.plot(data['Year'], data['Total'], marker='o', linestyle='-', color='b')
plt.title('Year-wise Total Rainfall (1900-2024)')
plt.xlabel('Year')
plt.ylabel('Total Rainfall (mm)')
plt.grid(True)
plt.show()

# %%
data = data[(data['Year'] >= '1999') & (data['Year'] <= '2024')]
data.loc[:, 'Max Month'] = data.loc[:, ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']].idxmax(axis=1)
data.loc[:, 'Max Rainfall'] = data.loc[:, ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']].max(axis=1)
plt.figure(figsize=(14, 8))
plt.scatter(data['Year'], data['Max Rainfall'], c='b', marker='o')
for i in range(len(data)):
    plt.text(data['Year'].iloc[i], data['Max Rainfall'].iloc[i], data['Max Month'].iloc[i], fontsize=9)
plt.title('Month of Highest Rainfall for Each Year (1999-2024)')
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.grid(True)
plt.show()

# %%
data_filtered = data[(data['Year'] >= '1999') & (data['Year'] <= '2023')]


average_rainfall = data_filtered['Total'].mean()


plt.figure(figsize=(14, 8))
plt.bar(data_filtered['Year'], data_filtered['Total'], color='blue', edgecolor='black', label='Total Rainfall')
plt.axhline(y=average_rainfall, color='r', linestyle='--', label='Average Rainfall')
plt.title('Total Rainfall (1999-2023) with Average Rainfall')
plt.xlabel('Year')
plt.ylabel('Total Rainfall (mm)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the rainfall data from 1999 to 2023, several key insights can be drawn. The total rainfall for each year shows significant variability, with some years experiencing much higher rainfall than others. For instance, 2022 recorded an exceptionally high total rainfall of 1957.7 mm, while 2003 had a much lower total of 678.7 mm. This variability can be attributed to climatic phenomena such as El Niño and La Niña, which have a notable impact on rainfall patterns. El Niño years, like 2023, tend to have lower rainfall, while La Niña years, such as 2022, often see higher rainfall.
#
# The bar chart visualizing the total rainfall for each year between 1999 and 2023, with a line indicating the average rainfall, provides a clear picture of these fluctuations. The average rainfall over this period is approximately 1077.1 mm, as indicated by the red dashed line. Years with rainfall significantly above or below this average are easily identifiable, highlighting the impact of climatic events.
#
# Additionally, the scatter plot showing the month with the highest rainfall for each year between 1999 and 2024 reveals interesting patterns. For example, May and September are frequently the months with the highest rainfall, indicating the influence of the monsoon season. This information is crucial for understanding seasonal rainfall distribution and planning for water resource management.
#
# Overall, these visualizations and analyses provide valuable insights into the rainfall patterns in Bangalore, helping to understand long-term trends and the impact of climatic phenomena on annual rainfall.
